# %% [markdown]
# # Capstone project

# %%
import pandas as pd  
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# Read apple.csv and tesla.csv file
apple_df = pd.read_csv("apple.csv",parse_dates=["Date"])
apple_df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1980-12-12    0.128348    0.128906    0.128348    0.128348    0.100323
# 1     1980-12-15    0.122210    0.122210    0.121652    0.121652    0.095089
# 2     1980-12-16    0.113281    0.113281    0.112723    0.112723    0.088110
# 3     1980-12-17    0.115513    0.116071    0.115513    0.115513    0.090291
# 4     1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092908
# ...          ...         ...         ...         ...         ...         ...
# 10404 2022-03-18  160.509995  164.479996  159.759995  163.979996  163.979996
# 10405 2022-03-21  163.509995  166.350006  163.009995  165.380005  165.380005
# 10406 2022-03-22  165.509995  169.419998  164.910004  168.820007  168.820007
# 10407 2022-03-23  167.990005  172.639999  167.649994  170.210007  170.210007
# 10408 2022-03-24  171.059998  174.139999  170.210007  174.070007  174.070007
#
#           Volume
# 0      469033600
# ...

# %%
##Recognizing Datasets

# %%
tesla_df = pd.read_csv("tesla.csv",parse_dates=["Date"])
tesla_df
# Out:
#            Date         Open         High         Low        Close  \
# 0    2010-06-29     3.800000     5.000000    3.508000     4.778000
# 1    2010-06-30     5.158000     6.084000    4.660000     4.766000
# 2    2010-07-01     5.000000     5.184000    4.054000     4.392000
# 3    2010-07-02     4.600000     4.620000    3.742000     3.840000
# 4    2010-07-06     4.000000     4.000000    3.166000     3.222000
# ...         ...          ...          ...         ...          ...
# 2951 2022-03-18   874.489990   907.849976  867.390015   905.390015
# 2952 2022-03-21   914.979980   942.849976  907.090027   921.159973
# 2953 2022-03-22   930.000000   997.859985  921.750000   993.979980
# 2954 2022-03-23   979.940002  1040.699951  976.400024   999.109985
# 2955 2022-03-24  1009.729980  1024.489990  988.799988  1013.919983
#
#         Adj Close    Volume
# 0        4.778000  93831500
# 1        4.766000  85935500
# 2        4.392000  41094000
# 3        3.840000  25699000
# ...

# %%
##### 2. What is the shape for stocks data
tesla_df.shape
# Out:
# (2956, 7)

# %%
apple_df.shape
# Out:
# (10409, 7)

# %%
print(apple_df.shape)
print(tesla_df.shape)
# Out:
# (10409, 7)
# (2956, 7)

# %%
apple_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10409 entries, 0 to 10408
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       10409 non-null  datetime64[ns]
#  1   Open       10409 non-null  float64
#  2   High       10409 non-null  float64
#  3   Low        10409 non-null  float64
#  4   Close      10409 non-null  float64
#  5   Adj Close  10409 non-null  float64
#  6   Volume     10409 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 569.4 KB

# %%
apple_df.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100323  469033600
# 1 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.095089  175884800
# 2 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.088110  105728000
# 3 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090291   86441600
# 4 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092908   73449600

# %%
apple_df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 10404 2022-03-18  160.509995  164.479996  159.759995  163.979996  163.979996
# 10405 2022-03-21  163.509995  166.350006  163.009995  165.380005  165.380005
# 10406 2022-03-22  165.509995  169.419998  164.910004  168.820007  168.820007
# 10407 2022-03-23  167.990005  172.639999  167.649994  170.210007  170.210007
# 10408 2022-03-24  171.059998  174.139999  170.210007  174.070007  174.070007
#
#           Volume
# 10404  123351200
# 10405   95811400
# 10406   81532000
# 10407   98062700
# 10408   90018700

# %%
apple_df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
apple_df.index
# Out:
# RangeIndex(start=0, stop=10409, step=1)

# %%
apple_df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
apple_df.describe().T
# Out:
#              count                           mean                  min  \
# Date         10409  2001-07-26 11:23:49.416850816  1980-12-12 00:00:00
# Open       10409.0                       13.95991             0.049665
# High       10409.0                      14.111936             0.049665
# Low        10409.0                      13.809163             0.049107
# Close      10409.0                      13.966757             0.049107
# Adj Close  10409.0                      13.350337             0.038384
# Volume     10409.0               332177847.170718                  0.0
#
#                            25%                  50%                  75%  \
# Date       1991-04-01 00:00:00  2001-07-18 00:00:00  2011-11-18 00:00:00
# Open                  0.281964              0.46875            14.217857
# High                  0.287946             0.477679            14.364286
# Low                   0.274554             0.459821            14.043571
# ...

# %%
apple_df.median()
# Out:
# Date         2001-07-18 00:00:00
# Open                     0.46875
# High                    0.477679
# Low                     0.459821
# Close                    0.46875
# Adj Close               0.386853
# Volume               219968000.0
# dtype: object

# %%
tesla_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2956 entries, 0 to 2955
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2956 non-null   datetime64[ns]
#  1   Open       2956 non-null   float64
#  2   High       2956 non-null   float64
#  3   Low        2956 non-null   float64
#  4   Close      2956 non-null   float64
#  5   Adj Close  2956 non-null   float64
#  6   Volume     2956 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 161.8 KB

# %%
tesla_df.head()
# Out:
#         Date   Open   High    Low  Close  Adj Close    Volume
# 0 2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 1 2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 3 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 4 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %%
tesla_df.tail()
# Out:
#            Date         Open         High         Low        Close  \
# 2951 2022-03-18   874.489990   907.849976  867.390015   905.390015
# 2952 2022-03-21   914.979980   942.849976  907.090027   921.159973
# 2953 2022-03-22   930.000000   997.859985  921.750000   993.979980
# 2954 2022-03-23   979.940002  1040.699951  976.400024   999.109985
# 2955 2022-03-24  1009.729980  1024.489990  988.799988  1013.919983
#
#         Adj Close    Volume
# 2951   905.390015  33408500
# 2952   921.159973  27327200
# 2953   993.979980  35289500
# 2954   999.109985  40225400
# 2955  1013.919983  22901900

# %%
tesla_df.describe().T
# Out:
#             count                           mean                  min  \
# Date         2956  2016-05-11 07:21:21.190798336  2010-06-29 00:00:00
# Open       2956.0                     138.691296                3.228
# High       2956.0                     141.771603                3.326
# Low        2956.0                     135.425953                2.996
# Close      2956.0                     138.762183                 3.16
# Adj Close  2956.0                     138.762183                 3.16
# Volume     2956.0                31314485.723951             592500.0
#
#                            25%                  50%                  75%  \
# Date       2013-06-05 18:00:00  2016-05-11 12:00:00  2019-04-19 00:00:00
# Open                    19.627            46.656999            68.057001
# High                    20.402            47.487001              69.3575
# Low                    19.1275            45.820002            66.911501
# ...

# %%
tesla_df.median()
# Out:
# Date         2016-05-11 12:00:00
# Open                   46.656999
# High                   47.487001
# Low                    45.820002
# Close                     46.545
# Adj Close                 46.545
# Volume                24886800.0
# dtype: object

# %%
tesla_df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
tesla_df.values
# Out:
# array([[Timestamp('2010-06-29 00:00:00'), 3.8, 5.0, ..., 4.778, 4.778,
#         93831500],
#        [Timestamp('2010-06-30 00:00:00'), 5.158, 6.084, ..., 4.766,
#         4.766, 85935500],
#        [Timestamp('2010-07-01 00:00:00'), 5.0, 5.184, ..., 4.392, 4.392,
#         41094000],
#        ...,
#        [Timestamp('2022-03-22 00:00:00'), 930.0, 997.859985, ...,
#         993.97998, 993.97998, 35289500],
#        [Timestamp('2022-03-23 00:00:00'), 979.940002, 1040.699951, ...,
#         999.109985, 999.109985, 40225400],
#        [Timestamp('2022-03-24 00:00:00'), 1009.72998, 1024.48999, ...,
#         1013.919983, 1013.919983, 22901900]], dtype=object)

# %%
tesla_df.index
# Out:
# RangeIndex(start=0, stop=2956, step=1)

# %%
tesla_df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
tesla_df.nunique()
# Out:
# Date         2956
# Open         2666
# High         2662
# Low          2672
# Close        2764
# Adj Close    2764
# Volume       2925
# dtype: int64

# %%
apple_df.nunique()
# Out:
# Date         10409
# Open          5765
# High          5704
# Low           5682
# Close         5871
# Adj Close     7397
# Volume        9846
# dtype: int64

# %%
apple_df = apple_df.drop_duplicates()
apple_df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1980-12-12    0.128348    0.128906    0.128348    0.128348    0.100323
# 1     1980-12-15    0.122210    0.122210    0.121652    0.121652    0.095089
# 2     1980-12-16    0.113281    0.113281    0.112723    0.112723    0.088110
# 3     1980-12-17    0.115513    0.116071    0.115513    0.115513    0.090291
# 4     1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092908
# ...          ...         ...         ...         ...         ...         ...
# 10404 2022-03-18  160.509995  164.479996  159.759995  163.979996  163.979996
# 10405 2022-03-21  163.509995  166.350006  163.009995  165.380005  165.380005
# 10406 2022-03-22  165.509995  169.419998  164.910004  168.820007  168.820007
# 10407 2022-03-23  167.990005  172.639999  167.649994  170.210007  170.210007
# 10408 2022-03-24  171.059998  174.139999  170.210007  174.070007  174.070007
#
#           Volume
# 0      469033600
# ...

# %%
tesla_df = tesla_df.drop_duplicates()
tesla_df
# Out:
#            Date         Open         High         Low        Close  \
# 0    2010-06-29     3.800000     5.000000    3.508000     4.778000
# 1    2010-06-30     5.158000     6.084000    4.660000     4.766000
# 2    2010-07-01     5.000000     5.184000    4.054000     4.392000
# 3    2010-07-02     4.600000     4.620000    3.742000     3.840000
# 4    2010-07-06     4.000000     4.000000    3.166000     3.222000
# ...         ...          ...          ...         ...          ...
# 2951 2022-03-18   874.489990   907.849976  867.390015   905.390015
# 2952 2022-03-21   914.979980   942.849976  907.090027   921.159973
# 2953 2022-03-22   930.000000   997.859985  921.750000   993.979980
# 2954 2022-03-23   979.940002  1040.699951  976.400024   999.109985
# 2955 2022-03-24  1009.729980  1024.489990  988.799988  1013.919983
#
#         Adj Close    Volume
# 0        4.778000  93831500
# 1        4.766000  85935500
# 2        4.392000  41094000
# 3        3.840000  25699000
# ...

# %%
##### 3. Reading specific columns

# %%
# read `Date` and `Close` columns from tesla stock data
tesla_column_df = tesla_df [["Date","Close"]]
tesla_column_df
# Out:
#            Date        Close
# 0    2010-06-29     4.778000
# 1    2010-06-30     4.766000
# 2    2010-07-01     4.392000
# 3    2010-07-02     3.840000
# 4    2010-07-06     3.222000
# ...         ...          ...
# 2951 2022-03-18   905.390015
# 2952 2022-03-21   921.159973
# 2953 2022-03-22   993.979980
# 2954 2022-03-23   999.109985
# 2955 2022-03-24  1013.919983
#
# [2956 rows x 2 columns]

# %%
##### 4. Read specific rows

# %%
# read the March 2022 apple stock data
# read in the CSV file and filter the rows for the month of March 2022
apple_row_df = pd.read_csv('apple.csv', parse_dates=['Date'])

# %%
apple_row_df = apple_row_df[apple_row_df['Date'].dt.month == 3]
apple_row_df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 53    1981-03-02    0.118862    0.119420    0.118862    0.118862    0.092908
# 54    1981-03-03    0.117746    0.117746    0.117188    0.117188    0.091600
# 55    1981-03-04    0.116629    0.116629    0.116071    0.116071    0.090727
# 56    1981-03-05    0.116071    0.116071    0.115513    0.115513    0.090291
# 57    1981-03-06    0.115513    0.115513    0.114397    0.114397    0.089418
# ...          ...         ...         ...         ...         ...         ...
# 10404 2022-03-18  160.509995  164.479996  159.759995  163.979996  163.979996
# 10405 2022-03-21  163.509995  166.350006  163.009995  165.380005  165.380005
# 10406 2022-03-22  165.509995  169.419998  164.910004  168.820007  168.820007
# 10407 2022-03-23  167.990005  172.639999  167.649994  170.210007  170.210007
# 10408 2022-03-24  171.059998  174.139999  170.210007  174.070007  174.070007
#
#           Volume
# 53      11760000
# ...

# %%
apple_row_df = apple_row_df[apple_row_df['Date'].dt.year == 2022] 
apple_row_df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 10391 2022-03-01  164.699997  166.600006  161.970001  163.199997  163.199997
# 10392 2022-03-02  164.389999  167.360001  162.949997  166.559998  166.559998
# 10393 2022-03-03  168.470001  168.910004  165.550003  166.229996  166.229996
# 10394 2022-03-04  164.490005  165.550003  162.100006  163.169998  163.169998
# 10395 2022-03-07  163.360001  165.020004  159.039993  159.300003  159.300003
# 10396 2022-03-08  158.820007  162.880005  155.800003  157.440002  157.440002
# 10397 2022-03-09  161.479996  163.410004  159.410004  162.949997  162.949997
# 10398 2022-03-10  160.199997  160.389999  155.979996  158.520004  158.520004
# 10399 2022-03-11  158.929993  159.279999  154.500000  154.729996  154.729996
# 10400 2022-03-14  151.449997  154.119995  150.100006  150.619995  150.619995
# 10401 2022-03-15  150.899994  155.570007  150.380005  155.089996  155.089996
# ...

# %%
apple_row_df = apple_row_df[(apple_row_df["Date"].dt.month==3) & (apple_row_df["Date"].dt.year==2022)]
apple_row_df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 10391 2022-03-01  164.699997  166.600006  161.970001  163.199997  163.199997
# 10392 2022-03-02  164.389999  167.360001  162.949997  166.559998  166.559998
# 10393 2022-03-03  168.470001  168.910004  165.550003  166.229996  166.229996
# 10394 2022-03-04  164.490005  165.550003  162.100006  163.169998  163.169998
# 10395 2022-03-07  163.360001  165.020004  159.039993  159.300003  159.300003
# 10396 2022-03-08  158.820007  162.880005  155.800003  157.440002  157.440002
# 10397 2022-03-09  161.479996  163.410004  159.410004  162.949997  162.949997
# 10398 2022-03-10  160.199997  160.389999  155.979996  158.520004  158.520004
# 10399 2022-03-11  158.929993  159.279999  154.500000  154.729996  154.729996
# 10400 2022-03-14  151.449997  154.119995  150.100006  150.619995  150.619995
# 10401 2022-03-15  150.899994  155.570007  150.380005  155.089996  155.089996
# ...

# %%
apple_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 10391 to 10408
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       18 non-null     datetime64[ns]
#  1   Open       18 non-null     float64
#  2   High       18 non-null     float64
#  3   Low        18 non-null     float64
#  4   Close      18 non-null     float64
#  5   Adj Close  18 non-null     float64
#  6   Volume     18 non-null     int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 1.1 KB

# %%
apple_df.head()
apple_df.describe().T
# Out:
#           count                 mean                  min  \
# Date         18  2022-03-12 12:00:00  2022-03-01 00:00:00
# Open       18.0            161.74611           150.899994
# High       18.0           164.284446           154.119995
# Low        18.0           159.745001           150.100006
# Close      18.0           162.248889           150.619995
# Adj Close  18.0           162.248889           150.619995
# Volume     18.0           95177950.0           75615400.0
#
#                            25%                  50%                  75%  \
# Date       2022-03-07 06:00:00  2022-03-12 12:00:00  2022-03-17 18:00:00
# Open                158.847504           162.419999           164.647499
# High                160.542499               164.75           167.170002
# Low                 155.845001           159.584999           162.994996
# Close               158.715004           163.059998           166.017498
# ...

# %%
##### 5. What is the mean closing price of Apple
round(apple_df["Close"].mean(),)
# Out:
# 162

# %%
##### 6. Select the correct mean
apple_df.mean()
# Out:
# Date         2022-03-12 12:00:00
# Open                   161.74611
# High                  164.284446
# Low                   159.745001
# Close                 162.248889
# Adj Close             162.248889
# Volume                95177950.0
# dtype: object

# %%
tesla_df.mean()
# Out:
# Date         2016-05-11 07:21:21.190798336
# Open                            138.691296
# High                            141.771603
# Low                             135.425953
# Close                           138.762183
# Adj Close                       138.762183
# Volume                     31314485.723951
# dtype: object

# %%
##### 7. Find the maximum and minimum values
tesla_df["Close"].describe()
apple_df["Close"].describe()
# Out:
# count     18.000000
# mean     162.248889
# std        5.912308
# min      150.619995
# 25%      158.715004
# 50%      163.059998
# 75%      166.017498
# max      174.070007
# Name: Close, dtype: float64

# %%
##### 8. Find the average and median values
apple_df["Close"].describe()
# Out:
# count     18.000000
# mean     162.248889
# std        5.912308
# min      150.619995
# 25%      158.715004
# 50%      163.059998
# 75%      166.017498
# max      174.070007
# Name: Close, dtype: float64

# %%
##### 9. Create a new column
# Create a new column `High_Low_Diff` in tesla and apple stock data

# creating a new column 'High_Low_Diff' in the Apple data
apple_df['High_Low_Diff'] = apple_df['High'] - apple_df['Low']

# creating a new column 'High_Low_Diff' in the Tesla data
tesla_df['High_Low_Diff'] = tesla_df['High'] - tesla_df['Low']

# %%
apple_df["Close"].median()

tesla_df["Close"].mean()
# Out:
# 138.7621830964141

# %%
##### 10. Rename columns

apple_df= apple_df.rename(columns={'Open': 'Apple_Open', 'High': 'Apple_High', 'Low': 'Apple_Low', 'Close': 'Apple_Close', 'Adj Close': 'Apple_Adj_Close', 'Volume': 'Apple_Volume'})
tesla_df= tesla_df.rename(columns= {'Open': 'Tesla_Open', 'High': 'Tesla_High', 'Low': 'Tesla_Low', 'Close': 'Tesla_Close', 'Adj Close': 'Tesla_Adj_Close', 'Volume': 'Tesla_Volume'})

# %%
##### 11. Drop all the rows of may 2022

# %%
indexApple = apple_df[(apple_df['Date'] >= pd.to_datetime('2021-05-01')) & (apple_df['Date'] <= pd.to_datetime('2021-05-31'))].index
apple_df.drop(indexApple , inplace=True)

indexTesla = tesla_df[(tesla_df['Date'] >= pd.to_datetime('2021-05-01')) & (tesla_df['Date'] <= pd.to_datetime('2021-05-31'))].index
tesla_df.drop(indexTesla , inplace=True)

# %%
##### 12. Create new rows

# create a new row using below data:
# Apple dataset new row details:

# {'Date': pd.to_datetime('2021-02-18'), 'Apple_Open': 300.0, 'Apple_High': 305.0, 'Apple_Low': 295.0, 'Apple_Close': 303.0, 'Apple_Adj_Close': 303.0, 'Apple_Volume': 50000000, 'High_Low_Diff': 10.0}

# Tesla dataset new row details:

# {'Date': pd.to_datetime('2021-02-18'), 'Tesla_Open': 700.0, 'Tesla_High': 710.0, 'Tesla_Low': 690.0, 'Tesla_Close': 702.0, 'Tesla_Adj_Close': 702.0, 'Tesla_Volume': 20000000, 'High_Low_Diff': 20.0}
# creating a new row for the next day in the Apple data

# %%
# creating a new row for the next day in the Apple data
new_apple_row = {'Date': pd.to_datetime('2020-02-18'), 'Apple_Open': 300.0, 'Apple_High': 305.0, 'Apple_Low': 295.0, 'Apple_Close': 303.0, 'Apple_Adj_Close': 303.0, 'Apple_Volume': 50000000, 'High_Low_Diff': 10.0}
apple_df = pd.concat([apple_df, pd.DataFrame([new_apple_row])], ignore_index=True)

# creating a new row for the next day in the Tesla data
new_tesla_row = {'Date': pd.to_datetime('2020-02-18'), 'Tesla_Open': 700.0, 'Tesla_High': 710.0, 'Tesla_Low': 690.0, 'Tesla_Close': 702.0, 'Tesla_Adj_Close': 702.0, 'Tesla_Volume': 20000000, 'High_Low_Diff': 20.0}
tesla_df = pd.concat([tesla_df, pd.DataFrame([new_tesla_row])], ignore_index=True)

# %%
#####  Which month has maximum Close value
print(apple_monthly.max())
print(tesla_monthly.max())
# Out:
# 2920.479995
# 44527.205857

# %%
print(apple_monthly.idxmax())
print(tesla_monthly.idxmax())
# Out:
# March
# January

# %%
### Group Activity

# group the Apple data by month 
apple_monthly = apple_df.groupby(apple_df['Date'].dt.strftime('%B'))['Apple_Close'].sum().sort_values()

# group the Tesla data by month 
tesla_monthly = tesla_df.groupby(tesla_df['Date'].dt.strftime('%B'))['Tesla_Close'].sum().sort_values()

# %%
print(apple_monthly)
# Out:
# Date
# February    1212.000000
# March       2920.479995
# Name: Apple_Close, dtype: float64

# %%
print(tesla_monthly)
# Out:
# Date
# May          10159.416056
# April        24443.860007
# June         25567.180070
# July         27875.339909
# August       31329.839739
# September    32021.460046
# October      35946.789986
# March        40104.141784
# November     40503.068013
# February     43699.485929
# December     44476.165841
# January      44527.205857
# Name: Tesla_Close, dtype: float64

# %%
##### 13. Which month has minimum Close value

print(apple_monthly.min())
print(tesla_monthly.min())

print(apple_monthly.idxmin())
print(tesla_monthly.idxmin())
# Out:
# 909.0
# 10159.416056
# February
# May

# %%
##### 14. Which month has maximum Close value
print(apple_monthly.max())
print(tesla_monthly.max())

print(apple_monthly.idxmax())
print(tesla_monthly.idxmax())
# Out:
# 2920.479995
# 44527.205857
# March
# January

# %%
##### 16. Write the mean of the Close value
print(apple_monthly.mean())
print(tesla_monthly.mean())
# Out:
# 1914.7399975
# 33329.32943641667

# %% [markdown]
# # Activities on filtering

# %%
##### 17. Filter the data based on specific criteria

# try your code here
apple_pos = apple_df.loc[apple_df["Apple_Close"] >  apple_df ["Apple_Open"]]
apple_pos
# Out:
#          Date  Apple_Open  Apple_High   Apple_Low  Apple_Close  \
# 1  2022-03-02  164.389999  167.360001  162.949997   166.559998
# 6  2022-03-09  161.479996  163.410004  159.410004   162.949997
# 10 2022-03-15  150.899994  155.570007  150.380005   155.089996
# 11 2022-03-16  157.050003  160.000000  154.460007   159.589996
# 12 2022-03-17  158.610001  161.000000  157.630005   160.619995
# 13 2022-03-18  160.509995  164.479996  159.759995   163.979996
# 14 2022-03-21  163.509995  166.350006  163.009995   165.380005
# 15 2022-03-22  165.509995  169.419998  164.910004   168.820007
# 16 2022-03-23  167.990005  172.639999  167.649994   170.210007
# 17 2022-03-24  171.059998  174.139999  170.210007   174.070007
# 18 2023-02-18  300.000000  305.000000  295.000000   303.000000
# 19 2021-02-18  300.000000  305.000000  295.000000   303.000000
# 20 2021-02-18  300.000000  305.000000  295.000000   303.000000
# 21 2020-02-18  300.000000  305.000000  295.000000   303.000000
#
# ...

# %%
tesla_pos = tesla_df.loc[tesla_df["Tesla_Close"] > tesla_df["Tesla_Open"]]
tesla_pos
# Out:
#            Date  Tesla_Open  Tesla_High   Tesla_Low  Tesla_Close  \
# 0    2010-06-29     3.80000     5.00000    3.508000     4.778000
# 6    2010-07-08     3.22800     3.50400    3.114000     3.492000
# 9    2010-07-13     3.47800     3.72800    3.380000     3.628000
# 10   2010-07-14     3.58800     4.03000    3.552000     3.968000
# 13   2010-07-19     4.27400     4.45000    4.184000     4.382000
# ...         ...         ...         ...         ...          ...
# 2935 2022-03-24  1009.72998  1024.48999  988.799988  1013.919983
# 2936 2023-02-18   700.00000   710.00000  690.000000   702.000000
# 2937 2021-02-18   700.00000   710.00000  690.000000   702.000000
# 2938 2021-02-18   700.00000   710.00000  690.000000   702.000000
# 2939 2020-02-18   700.00000   710.00000  690.000000   702.000000
#
#       Tesla_Adj_Close  Tesla_Volume  High_Low_Diff
# 0            4.778000      93831500            NaN
# 6            3.492000      38557000            NaN
# ...

# %%
##### 18. What is the shape of above filtered `apple_pos` dataframe
apple_pos.shape
# Out:
# (14, 8)

# %%
##### 19. What is the shape of above filtered `tesla_pos` dataframe

tesla_pos.shape
# Out:
# (1463, 8)

# %%
##### 20. Filter Data Using Multiple Criteria

# filter the data using multiple condition
# filter the data using multiple condition
apple_filtered = apple_df.loc[(apple_df["Apple_Volume"] >50000000) & (apple_df["Apple_Close"] > apple_df["Apple_Open"])]
tesla_filtered = tesla_df.loc[(tesla_df["Tesla_Volume"] >50000000) & (tesla_df["Tesla_Close"] > tesla_df["Tesla_Open"])]

# %%
##### 21. Filter Data Based on Column Values
# filter the data based on common values
apple_filtered_close = apple_df.loc[(apple_df["Apple_Close"] >=280)]
tesla_filtered_close = tesla_df.loc[(tesla_df["Tesla_Close"] >=280)]

# %% [markdown]
# # Activities based on plots

# %%
##### 22. Read stock files and filter them for plotting.
# read the apple and tesla stock data from August 2022 onwards.

# read the apple.csv file
apple_df = pd.read_csv('apple.csv', parse_dates=['Date'])

# read the tesla.csv file
tesla_df = pd.read_csv('tesla.csv', parse_dates=['Date'])

# %%
apple_pos = apple_df.loc[(apple_df['Date'].dt.strftime('%Y-%m') == '2021-08') & (apple_df['Close'] > apple_df['Open'])]
apple_pos
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 10246 2021-08-03  145.809998  148.039993  145.179993  147.360001  146.738159
# 10248 2021-08-05  146.979996  147.839996  146.169998  147.059998  146.439423
# 10253 2021-08-12  146.190002  149.050003  145.839996  148.889999  148.483841
# 10254 2021-08-13  148.970001  149.440002  148.270004  149.100006  148.693283
# 10255 2021-08-16  148.539993  151.190002  146.470001  151.119995  150.707748
# 10258 2021-08-19  145.029999  148.000000  144.500000  146.699997  146.299805
# 10259 2021-08-20  147.440002  148.500000  146.779999  148.190002  147.785751
# 10260 2021-08-23  148.309998  150.190002  147.889999  149.710007  149.301620
# 10261 2021-08-24  149.449997  150.860001  149.149994  149.619995  149.211838
# 10264 2021-08-27  147.479996  148.750000  146.830002  148.600006  148.194641
# 10265 2021-08-30  149.000000  153.490005  148.610001  153.119995  152.702301
#
#           Volume
# 10246   64786600
# ...

# %%
tesla_pos = tesla_df.loc[(tesla_df['Date'].dt.strftime('%Y-%m') == '2021-08') & (tesla_df['Close'] > tesla_df['Open'])]
tesla_pos
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 2792 2021-08-02  700.000000  726.940002  698.400024  709.669983  709.669983
# 2797 2021-08-09  710.169983  719.030029  705.130005  713.760010  713.760010
# 2800 2021-08-12  706.340027  722.799988  699.400024  722.250000  722.250000
# 2804 2021-08-18  669.750000  695.770020  669.349976  688.989990  688.989990
# 2807 2021-08-23  685.440002  712.130005  680.750000  706.299988  706.299988
# 2809 2021-08-25  707.030029  716.969971  704.000000  711.200012  711.200012
# 2811 2021-08-27  705.000000  715.000000  702.099976  711.919983  711.919983
# 2812 2021-08-30  714.719971  731.000000  712.729980  730.909973  730.909973
# 2813 2021-08-31  733.000000  740.390015  726.440002  735.719971  735.719971
#
#         Volume
# 2792  33615800
# 2797  14715300
# 2800  17459100
# 2804  20349400
# 2807  20264900
# 2809  12645600
# 2811  13833800
# 2812  18604200
# 2813  20855400

# %%
##### 22. Plot Apple Close prices in August 2022
# Plot the Apple Close prices in August 2022
ax = apple_pos.plot(kind="line",title="Apple Close Price from August 2021",x="Date",y="Close",color="black")

# %%
##### 23. Choose correct options based on above plot
# Plot the graph, visualize them and select the correct answer
apple_pos.plot(kind="line",title="Apple_Data",x="Date",y="Close")
tesla_pos.plot(kind="line",title="Tesla_Data",x="Date",y="Close")

# plot the line chart for apple_pos dataframe
apple_pos.plot(x='Date', y='Volume', title='Apple Volume from August 2021', color='black')

# plot the line chart for tesla_pos dataframe
tesla_pos.plot(x='Date', y='Volume', title='Tesla Volume from August 2021', color='black')
# Out:
# <Axes: title={'center': 'Tesla Volume from August 2021'}, xlabel='Date'>

# %%
##### 25. Choose correct options based on line plot
# Plot the graph, visualize them and select the correct answer
apple_pos.plot(kind="line",title="Apple_Data",x="Date",y="Volume")
apple_pos.plot(kind="line",title="Tesla_Data",x="Date",y="Volume")
# Out:
# <Axes: title={'center': 'Tesla_Data'}, xlabel='Date'>

# %%
##### 26. Choose correct options based on bar plot
# plot the bar chart for the filterd dataset between Date and Volume
apple_pos.plot(kind="bar",x="Date",y="Volume",title="Apple Volume from August 2021" )
tesla_pos.plot(kind="bar",x='Date', y='Volume', title="Tesla Volume from August 2021")
# Out:
# <Axes: title={'center': 'Tesla Volume from August 2021'}, xlabel='Date'>

# %%
##### 27. Choose correct options based on bar plot
# plot the bar chart for the above dataset between Date and Close
apple_pos.plot(kind="bar",x="Date",y="Close",title="Apple Volume from August 2021")
tesla_pos.plot(kind="bar",x="Date",y="Close",title="Tesla Volume from August 2021")
# Out:
# <Axes: title={'center': 'Tesla Volume from August 2021'}, xlabel='Date'>

# %%
##### 28. Choose correct based on scatter plot
# plot the scatter plot for the above dataset between Date and Close
apple_pos.plot(kind="scatter",x="Date",y="Close",title="Apple Volume from August 2021")
tesla_pos.plot(kind="scatter",x="Date",y="Close",title="Tesla Volume from August 2021")
# Out:
# <Axes: title={'center': 'Tesla Volume from August 2021'}, xlabel='Date', ylabel='Close'>

# %% [markdown]
# # End!
